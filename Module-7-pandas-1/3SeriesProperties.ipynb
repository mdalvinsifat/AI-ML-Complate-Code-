# %%
import pandas as pd

# %%
# propertice sob same thaka lagbe apni jodi 5 ta indexing den and 6 ta label den tahole milbe na apnake 6 tai dewa labe and 2 tai jodi je kono 2 ta valo object thake tahole ata object hobe 
sl = pd.Series([23,40,83,41,57,"abc"], index=["Masud", "sajol", "popon", "Sifat", "israfil", 25])

print(sl)
# Out:
# Masud       23
# sajol       40
# popon       83
# Sifat       41
# israfil     57
# 25         abc
# dtype: object

# %%
# vectorizOparations 

s1 = pd.Series([12, 52,73,44,54])
s2 = pd.Series([45, 45,88,75,56])

print(s1 + s2 )


# exmple you need a change a value 

s1[0] = 100 
print(s1)
# Out:
# 0     57
# 1     97
# 2    161
# 3    119
# 4    110
# dtype: int64
# 0    100
# 1     52
# 2     73
# 3     44
# 4     54
# dtype: int64
