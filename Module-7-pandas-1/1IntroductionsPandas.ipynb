# %%
import pandas as pd 
info= {
    "name":["rahul", "Harshita", "Shardha"], 
    "CGPA":[2.56,67.34,56.54]
}


df = pd.DataFrame(info)
print(df)
# Out:
#        name   CGPA
# 0     rahul   2.56
# 1  Harshita  67.34
# 2   Shardha  56.54

# %%
df
# Out:
#        name   CGPA
# 0     rahul   2.56
# 1  Harshita  67.34
# 2   Shardha  56.54
