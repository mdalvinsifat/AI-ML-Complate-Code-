# %%
import pandas as pd 

df = pd.read_csv("employee_data.csv")
print(df , type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
#methods
# 5st er 5 ta print korbe
# print(df.head())


# first er 2 ta print ashbe 
print(df.head(2))
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000
# 1   2    Bob   32         IT   72000

# %%
# last er 5 ta chole ashbe 
# df.tail()

# last er 3 ta chole ashbe 
df.tail(3)

# row and columns koyta ta dekhay 
df.shape
# Out:
# (10, 5)

# %%
# je kono akta ashbe random 
# df.sample()


# informations dey 
# df.info()

# df.shape


# df.describe()

# df.columns
# unique row dey 
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
