# %%
import pandas as pd

# %%
info= {

"info":["rakib","raju", "hasan"], 
"gpa":[4.67, 3.65, 2.67],
"age":[18, 20, 30]
}
# 1st way 
# dtaframe is 2D array 
df = pd.DataFrame(info)
print(df)

print(df.index)
print(df.columns)
# Out:
#     info   gpa  age
# 0  rakib  4.67   18
# 1   raju  3.65   20
# 2  hasan  2.67   30
# RangeIndex(start=0, stop=3, step=1)
# Index(['info', 'gpa', 'age'], dtype='str')

# %%
df
# Out:
#     info   gpa  age
# 0  rakib  4.67   18
# 1   raju  3.65   20
# 2  hasan  2.67   30

# %%
# 2nd way to create a datFrames 
df = pd.DataFrame([ ["hasan", 34] , ["sifat", 45],  ["Hasib", 34] ])
print(df)
# Out:
#        0   1
# 0  hasan  34
# 1  sifat  45
# 2  Hasib  34

# %%
# 3rd way to create a datFrames 
import numpy as np 
import pandas as pd
arr_numPy = np.array([ [1, 2, 3,] , [4, 5, 6]])

name = pd.DataFrame(arr_numPy, columns= ["A", "B", "C"] )

print(name)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
