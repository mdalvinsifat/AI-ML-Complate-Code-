# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")

df["country"]
df[["country", "city"]]


df.loc[5]

# 6 ta row print ashbe 
df.loc[1:6]

# 1:3 ata row and column ja ase tar nam diye call korte hobe 
df.loc[1:3, ["country", "city" , "latitude"]]


df.iloc[2]
# 8 ta row chole ashche 
df.iloc[1:8]


# [1:6] holo row and 1st column holo country ai jhono country value chole ashche 
df.iloc[1:6, 1]

# [1:6] holo row and 1st column holo 1 theke 4 number pojonto coulmn er value gulo ashche 
df.iloc[1:6, 1:4]

df.at[0, "city"]


df.iat[0, 8]
# Out:
# np.float64(6.539)
