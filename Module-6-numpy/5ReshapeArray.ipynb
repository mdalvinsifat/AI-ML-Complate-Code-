# %%
import numpy as np

# %%
arr = np.array([[1,2,3],[4,5,6]])

reshape = arr.reshape(3, 2)
# print(reshape, reshape.shape)

# convart to 2d array to 1d 
flatend = arr.flatten()
print(flatend, flatend.shape)
# Out:
# [1 2 3 4 5 6] (6,)
